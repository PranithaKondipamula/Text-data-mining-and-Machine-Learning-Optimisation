# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('relevant_model_outputs.xlsx')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Model                      17 non-null     object
#  1   Test Recall Range          17 non-null     float64
#  2   Test Recall Min            17 non-null     float64
#  3   Test Precision Min         17 non-null     float64
#  4   Test Lower CI              17 non-null     float64
#  5   Test Upper CI              17 non-null     float64
#  6   Test Accuracy              17 non-null     float64
#  7   Training Time (Seconds)    17 non-null     float64
#  8   Prediction Time (Seconds)  17 non-null     float64
#  9   Train Accuracy             17 non-null     float64
#  10  Overfit Status             17 non-null     object
#  11  Ensemble Recommendation    17 non-null     object
# dtypes: float64(9), object(3)
# memory usage: 1.7+ KB

# %%
plt.bar(df['Model'], df['Test Upper CI'], color = 'y')
plt.bar(df['Model'], df['Test Lower CI'], color = 'r')
plt.ylim([0.94,0.972])
plt.ylabel('Accuracy CI')
plt.xlabel('Model')
plt.title('New Categories - Best Models by CI')
plt.xticks(rotation=-90)
plt.figure(figsize=(20,20))
plt.show()

# %%
plt.scatter(range(len(df)), df['Test Accuracy'],color='blue')
for lower,upper,y in zip(df['Test Lower CI'],df['Test Upper CI'],range(len(df))):
    plt.plot((y,y),(lower,upper),'ro-',color='red')
plt.xticks(ticks = range(len(df)),labels = list(df['Model']),rotation=45, ha='right', rotation_mode='anchor')
plt.title('Accuracy C.I.s for the Top 17 Models')
plt.ylabel('Accuracy')
plt.xlabel('Model')
plt.show()
# Out:
# C:\Users\maxwe\AppData\Local\Temp\ipykernel_28556\3404537979.py:3: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot((y,y),(lower,upper),'ro-',color='red')
